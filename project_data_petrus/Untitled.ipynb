# %%
import pandas as pd

total_gov_expenditure = "total_gov_expenditure.csv"
total_gov_expenditure_df = pd.read_csv(total_gov_expenditure)
total_gov_expenditure_df = total_gov_expenditure_df.rename(columns={'2015 [YR2015]': 'Total 2015', '2016 [YR2016]': 'Total 2016', '2017 [YR2017]': 'Total 2017', '2018 [YR2018]': 'Total 2018', '2019 [YR2019]': 'Total 2019'})
total_gov_expenditure_df = total_gov_expenditure_df.drop(columns=['Series Code'])
total_gov_expenditure_df = total_gov_expenditure_df.drop([264, 265, 266, 267, 268])

total_gov_expenditure_df.head()
# Out:
#                                          Series Name    Country Name  \
# 0  Government expenditure on education, total (% ...     Afghanistan
# 1  Government expenditure on education, total (% ...         Albania
# 2  Government expenditure on education, total (% ...         Algeria
# 3  Government expenditure on education, total (% ...  American Samoa
# 4  Government expenditure on education, total (% ...         Andorra
#
#   Country Code   Total 2015   Total 2016   Total 2017   Total 2018  \
# 0          AFG  3.255800009  4.228360176  4.058869839           ..
# 1          ALB  3.437969923  3.962090015  3.611720085           ..
# 2          DZA           ..           ..           ..           ..
# 3          ASM           ..           ..           ..           ..
# 4          AND   3.28034997  3.237070084  3.217089891  3.246720076
#
#     Total 2019
# 0           ..
# 1           ..
# 2           ..
# 3           ..
# 4  3.151619911

# %%
total_gov_expenditure_df['Total 2015'] = pd.to_numeric(total_gov_expenditure_df['Total 2015'], errors='coerce')
total_gov_expenditure_df['Total 2016'] = pd.to_numeric(total_gov_expenditure_df['Total 2016'], errors='coerce')
total_gov_expenditure_df['Total 2017'] = pd.to_numeric(total_gov_expenditure_df['Total 2017'], errors='coerce')
total_gov_expenditure_df['Total 2018'] = pd.to_numeric(total_gov_expenditure_df['Total 2018'], errors='coerce')
total_gov_expenditure_df['Total 2019'] = pd.to_numeric(total_gov_expenditure_df['Total 2019'], errors='coerce')
total_gov_expenditure_df.dtypes
# Out:
# Series Name      object
# Country Name     object
# Country Code     object
# Total 2015      float64
# Total 2016      float64
# Total 2017      float64
# Total 2018      float64
# Total 2019      float64
# dtype: object

# %%
total_gov_expenditure_df.round(3)
# Out:
#                                            Series Name  \
# 0    Government expenditure on education, total (% ...
# 1    Government expenditure on education, total (% ...
# 2    Government expenditure on education, total (% ...
# 3    Government expenditure on education, total (% ...
# 4    Government expenditure on education, total (% ...
# ..                                                 ...
# 259  Government expenditure on education, total (% ...
# 260  Government expenditure on education, total (% ...
# 261  Government expenditure on education, total (% ...
# 262  Government expenditure on education, total (% ...
# 263  Government expenditure on education, total (% ...
#
#                                    Country Name Country Code  Total 2015  \
# 0                                   Afghanistan          AFG       3.256
# 1                                       Albania          ALB       3.438
# 2                                       Algeria          DZA         NaN
# 3                                American Samoa          ASM         NaN
# 4                                       Andorra          AND       3.280
# ..                                          ...          ...         ...
# 259                          Sub-Saharan Africa          SSF       4.148
# 260  Sub-Saharan Africa (excluding high income)          SSA       3.802
# 261   Sub-Saharan Africa (IDA & IBRD countries)          TSS       4.148
# 262                         Upper middle income          UMC         NaN
# 263                                       World          WLD       4.624
#
#      Total 2016  Total 2017  Total 2018  Total 2019
# 0         4.228       4.059         NaN         NaN
# 1         3.962       3.612         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4         3.237       3.217       3.247       3.152
# ..          ...         ...         ...         ...
# 259       3.258       4.031       4.304         NaN
# 260       3.096       3.917       3.989         NaN
# 261       3.258       4.031       4.304         NaN
# 262       3.813       4.093         NaN         NaN
# 263       4.459       4.529         NaN         NaN
#
# [264 rows x 8 columns]

# %%
secondary = "gov_expenditure_per_student_secondary.csv"
secondary_df = pd.read_csv(secondary)
secondary_df = secondary_df.rename(columns={'2015 [YR2015]': 'Total 2015', '2016 [YR2016]': 'Total 2016', '2017 [YR2017]': 'Total 2017', '2018 [YR2018]': 'Total 2018', '2019 [YR2019]': 'Total 2019'})
secondary_df = secondary_df.drop(columns=['Series Code'])
secondary_df = secondary_df.drop([264, 265, 266, 267, 268])
secondary_df
# Out:
#                                            Series Name  \
# 0    Government expenditure per student, secondary ...
# 1    Government expenditure per student, secondary ...
# 2    Government expenditure per student, secondary ...
# 3    Government expenditure per student, secondary ...
# 4    Government expenditure per student, secondary ...
# ..                                                 ...
# 259  Government expenditure per student, secondary ...
# 260  Government expenditure per student, secondary ...
# 261  Government expenditure per student, secondary ...
# 262  Government expenditure per student, secondary ...
# 263  Government expenditure per student, secondary ...
#
#                                    Country Name Country Code Total 2015  \
# 0                                   Afghanistan          AFG   10.29234
# 1                                       Albania          ALB    6.78368
# 2                                       Algeria          DZA         ..
# 3                                American Samoa          ASM         ..
# 4                                       Andorra          AND   14.38817
# ..                                          ...          ...        ...
# 259                          Sub-Saharan Africa          SSF         ..
# 260  Sub-Saharan Africa (excluding high income)          SSA         ..
# 261   Sub-Saharan Africa (IDA & IBRD countries)          TSS         ..
# 262                         Upper middle income          UMC         ..
# 263                                       World          WLD         ..
#
#     Total 2016 Total 2017 Total 2018 Total 2019
# 0     11.98575    11.3072         ..         ..
# 1      9.82258    7.97805         ..         ..
# 2           ..         ..         ..         ..
# 3           ..         ..         ..         ..
# 4     13.63639   13.56321   13.93424         ..
# ..         ...        ...        ...        ...
# 259         ..         ..         ..         ..
# 260         ..         ..         ..         ..
# 261         ..         ..         ..         ..
# 262         ..         ..         ..         ..
# 263         ..         ..         ..         ..
#
# [264 rows x 8 columns]

# %%
secondary_df['Total 2015'] = pd.to_numeric(secondary_df['Total 2015'], errors='coerce')
secondary_df['Total 2016'] = pd.to_numeric(secondary_df['Total 2016'], errors='coerce')
secondary_df['Total 2017'] = pd.to_numeric(secondary_df['Total 2017'], errors='coerce')
secondary_df['Total 2018'] = pd.to_numeric(secondary_df['Total 2018'], errors='coerce')
secondary_df['Total 2019'] = pd.to_numeric(secondary_df['Total 2019'], errors='coerce')
secondary_df.dtypes
# Out:
# Series Name      object
# Country Name     object
# Country Code     object
# Total 2015      float64
# Total 2016      float64
# Total 2017      float64
# Total 2018      float64
# Total 2019      float64
# dtype: object

# %%
secondary_df.round(3)
# Out:
#                                            Series Name  \
# 0    Government expenditure per student, secondary ...
# 1    Government expenditure per student, secondary ...
# 2    Government expenditure per student, secondary ...
# 3    Government expenditure per student, secondary ...
# 4    Government expenditure per student, secondary ...
# ..                                                 ...
# 259  Government expenditure per student, secondary ...
# 260  Government expenditure per student, secondary ...
# 261  Government expenditure per student, secondary ...
# 262  Government expenditure per student, secondary ...
# 263  Government expenditure per student, secondary ...
#
#                                    Country Name Country Code  Total 2015  \
# 0                                   Afghanistan          AFG      10.292
# 1                                       Albania          ALB       6.784
# 2                                       Algeria          DZA         NaN
# 3                                American Samoa          ASM         NaN
# 4                                       Andorra          AND      14.388
# ..                                          ...          ...         ...
# 259                          Sub-Saharan Africa          SSF         NaN
# 260  Sub-Saharan Africa (excluding high income)          SSA         NaN
# 261   Sub-Saharan Africa (IDA & IBRD countries)          TSS         NaN
# 262                         Upper middle income          UMC         NaN
# 263                                       World          WLD         NaN
#
#      Total 2016  Total 2017  Total 2018  Total 2019
# 0        11.986      11.307         NaN         NaN
# 1         9.823       7.978         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4        13.636      13.563      13.934         NaN
# ..          ...         ...         ...         ...
# 259         NaN         NaN         NaN         NaN
# 260         NaN         NaN         NaN         NaN
# 261         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN
#
# [264 rows x 8 columns]

# %%
tertiary = "gov_expenditure_per_student_tertiary.csv"
tertiary_df = pd.read_csv(tertiary)
tertiary_df = tertiary_df.rename(columns={'2015 [YR2015]': 'Total 2015', '2016 [YR2016]': 'Total 2016', '2017 [YR2017]': 'Total 2017', '2018 [YR2018]': 'Total 2018', '2019 [YR2019]': 'Total 2019'})
tertiary_df = tertiary_df.drop(columns=['Series Code'])
tertiary_df = tertiary_df.drop([264, 265, 266, 267, 268])
tertiary_df.head()
# Out:
#                                          Series Name    Country Name  \
# 0  Government expenditure per student, tertiary (...     Afghanistan
# 1  Government expenditure per student, tertiary (...         Albania
# 2  Government expenditure per student, tertiary (...         Algeria
# 3  Government expenditure per student, tertiary (...  American Samoa
# 4  Government expenditure per student, tertiary (...         Andorra
#
#   Country Code Total 2015 Total 2016 Total 2017 Total 2018 Total 2019
# 0          AFG         ..         ..         ..         ..         ..
# 1          ALB   12.88117   14.64597   13.78559         ..         ..
# 2          DZA         ..         ..         ..         ..         ..
# 3          ASM         ..         ..         ..         ..         ..
# 4          AND   27.73714   27.08058   23.66465   22.28547         ..

# %%
tertiary_df['Total 2015'] = pd.to_numeric(tertiary_df['Total 2015'], errors='coerce')
tertiary_df['Total 2016'] = pd.to_numeric(tertiary_df['Total 2016'], errors='coerce')
tertiary_df['Total 2017'] = pd.to_numeric(tertiary_df['Total 2017'], errors='coerce')
tertiary_df['Total 2018'] = pd.to_numeric(tertiary_df['Total 2018'], errors='coerce')
tertiary_df['Total 2019'] = pd.to_numeric(tertiary_df['Total 2019'], errors='coerce')
tertiary_df.dtypes
# Out:
# Series Name      object
# Country Name     object
# Country Code     object
# Total 2015      float64
# Total 2016      float64
# Total 2017      float64
# Total 2018      float64
# Total 2019      float64
# dtype: object

# %%
tertiary_df.round(3)
# Out:
#                                            Series Name  \
# 0    Government expenditure per student, tertiary (...
# 1    Government expenditure per student, tertiary (...
# 2    Government expenditure per student, tertiary (...
# 3    Government expenditure per student, tertiary (...
# 4    Government expenditure per student, tertiary (...
# ..                                                 ...
# 259  Government expenditure per student, tertiary (...
# 260  Government expenditure per student, tertiary (...
# 261  Government expenditure per student, tertiary (...
# 262  Government expenditure per student, tertiary (...
# 263  Government expenditure per student, tertiary (...
#
#                                    Country Name Country Code  Total 2015  \
# 0                                   Afghanistan          AFG         NaN
# 1                                       Albania          ALB      12.881
# 2                                       Algeria          DZA         NaN
# 3                                American Samoa          ASM         NaN
# 4                                       Andorra          AND      27.737
# ..                                          ...          ...         ...
# 259                          Sub-Saharan Africa          SSF         NaN
# 260  Sub-Saharan Africa (excluding high income)          SSA         NaN
# 261   Sub-Saharan Africa (IDA & IBRD countries)          TSS         NaN
# 262                         Upper middle income          UMC         NaN
# 263                                       World          WLD         NaN
#
#      Total 2016  Total 2017  Total 2018  Total 2019
# 0           NaN         NaN         NaN         NaN
# 1        14.646      13.786         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4        27.081      23.665      22.285         NaN
# ..          ...         ...         ...         ...
# 259         NaN         NaN         NaN         NaN
# 260         NaN         NaN         NaN         NaN
# 261         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN
#
# [264 rows x 8 columns]

# %%
primary = "gov_expenditure_per_student_primary.csv"
primary_df = pd.read_csv(primary)
primary_df = primary_df.rename(columns={'2015 [YR2015]': 'Total 2015', '2016 [YR2016]': 'Total 2016', '2017 [YR2017]': 'Total 2017', '2018 [YR2018]': 'Total 2018', '2019 [YR2019]': 'Total 2019'})
primary_df = primary_df.drop(columns=['Series Code'])
primary_df = primary_df.drop([264, 265, 266, 267, 268])
primary_df.head()
# Out:
#                                          Series Name    Country Name  \
# 0  Government expenditure per student, primary (%...     Afghanistan
# 1  Government expenditure per student, primary (%...         Albania
# 2  Government expenditure per student, primary (%...         Algeria
# 3  Government expenditure per student, primary (%...  American Samoa
# 4  Government expenditure per student, primary (%...         Andorra
#
#   Country Code Total 2015 Total 2016 Total 2017 Total 2018 Total 2019
# 0          AFG   10.24688   10.34081   10.25174         ..         ..
# 1          ALB   29.84568         ..   34.18148         ..         ..
# 2          DZA         ..         ..         ..         ..         ..
# 3          ASM         ..         ..         ..         ..         ..
# 4          AND   13.45657   12.74297   12.72411   12.30702         ..

# %%
primary_df['Total 2015'] = pd.to_numeric(primary_df['Total 2015'], errors='coerce')
primary_df['Total 2016'] = pd.to_numeric(primary_df['Total 2016'], errors='coerce')
primary_df['Total 2017'] = pd.to_numeric(primary_df['Total 2017'], errors='coerce')
primary_df['Total 2018'] = pd.to_numeric(primary_df['Total 2018'], errors='coerce')
primary_df['Total 2019'] = pd.to_numeric(primary_df['Total 2019'], errors='coerce')
primary_df.dtypes
# Out:
# Series Name      object
# Country Name     object
# Country Code     object
# Total 2015      float64
# Total 2016      float64
# Total 2017      float64
# Total 2018      float64
# Total 2019      float64
# dtype: object

# %%
primary_df.round(3)
# Out:
#                                            Series Name  \
# 0    Government expenditure per student, primary (%...
# 1    Government expenditure per student, primary (%...
# 2    Government expenditure per student, primary (%...
# 3    Government expenditure per student, primary (%...
# 4    Government expenditure per student, primary (%...
# ..                                                 ...
# 259  Government expenditure per student, primary (%...
# 260  Government expenditure per student, primary (%...
# 261  Government expenditure per student, primary (%...
# 262  Government expenditure per student, primary (%...
# 263  Government expenditure per student, primary (%...
#
#                                    Country Name Country Code  Total 2015  \
# 0                                   Afghanistan          AFG      10.247
# 1                                       Albania          ALB      29.846
# 2                                       Algeria          DZA         NaN
# 3                                American Samoa          ASM         NaN
# 4                                       Andorra          AND      13.457
# ..                                          ...          ...         ...
# 259                          Sub-Saharan Africa          SSF         NaN
# 260  Sub-Saharan Africa (excluding high income)          SSA         NaN
# 261   Sub-Saharan Africa (IDA & IBRD countries)          TSS         NaN
# 262                         Upper middle income          UMC         NaN
# 263                                       World          WLD         NaN
#
#      Total 2016  Total 2017  Total 2018  Total 2019
# 0        10.341      10.252         NaN         NaN
# 1           NaN      34.181         NaN         NaN
# 2           NaN         NaN         NaN         NaN
# 3           NaN         NaN         NaN         NaN
# 4        12.743      12.724      12.307         NaN
# ..          ...         ...         ...         ...
# 259         NaN         NaN         NaN         NaN
# 260         NaN         NaN         NaN         NaN
# 261         NaN         NaN         NaN         NaN
# 262         NaN         NaN         NaN         NaN
# 263         NaN         NaN         NaN         NaN
#
# [264 rows x 8 columns]
