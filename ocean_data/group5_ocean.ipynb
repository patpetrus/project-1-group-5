# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import sem
from scipy.stats import linregress

# %%
# Set path and read CSV
path = '../ocean_data/final_merge.csv'
merged_df = pd.read_csv(path)
merged_df
# Out:
#     Country Name  2015 Total Pop  2016 Total Pop  2017 Total Pop  \
# 0    Afghanistan      34413603.0      35383128.0      36296400.0
# 1        Albania       2880703.0       2876101.0       2873457.0
# 2        Algeria      39728025.0      40551404.0      41389198.0
# 3         Angola      27884381.0      28842484.0      29816748.0
# 4      Argentina      43131966.0      43590368.0      44044811.0
# ..           ...             ...             ...             ...
# 145    Venezuela      30081829.0      29846179.0      29390409.0
# 146      Vietnam      92677076.0      93638724.0      94596642.0
# 147        Yemen      26497889.0      27168210.0      27834821.0
# 148       Zambia      15879361.0      16363507.0      16853688.0
# 149     Zimbabwe      13814629.0      14030390.0      14236745.0
#
#      2018 Total Pop  2019 Total Pop  2015 Adults (%)  2016 Adults (%)  \
# 0        37172386.0      38041754.0        52.644299        53.207964
# 1         2866376.0       2854191.0        68.704725        68.660092
# 2        42228429.0      43053054.0        65.428845        64.857566
# 3        30809762.0      31825295.0        50.615167        50.685629
# 4        44494502.0      44938712.0        64.060020        64.060567
# ..              ...             ...              ...              ...
# 145      28870195.0      28515829.0        65.254716        65.139208
# 146      95540395.0      96462106.0        70.311813        70.138340
# 147      28498687.0      29161922.0        56.512238        56.810155
# 148      17351822.0      17861030.0        51.758764        52.090970
# 149      14439018.0      14645468.0        54.603457        54.473134
#
#      2017 Adults (%)  2018 Adults (%)  ...  2015 Female Literacy  \
# 0          53.763223        54.324898  ...                   NaN
# 1          68.642614        68.582390  ...                   NaN
# 2          64.183205        63.488825  ...                   NaN
# 3          50.807787        50.974702  ...                   NaN
# 4          64.083523        64.121277  ...             99.208771
# ..               ...              ...  ...                   ...
# 145        65.085698        65.066363  ...                   NaN
# 146        69.871421        69.552345  ...                   NaN
# 147        57.146968        57.508840  ...                   NaN
# 148        52.503824        52.964181  ...                   NaN
# 149        54.505941        54.659410  ...                   NaN
#
#      2016 Female Literacy  2017 Female Literacy  2018 Female Literacy  \
# 0                     NaN                   NaN             29.805210
# 1                     NaN                   NaN             97.761124
# 2                     NaN                   NaN             75.322968
# 3                     NaN                   NaN                   NaN
# 4               99.143097                   NaN             99.062042
# ..                    ...                   ...                   ...
# 145                   NaN                   NaN                   NaN
# 146                   NaN                   NaN             93.596710
# 147                   NaN                   NaN                   NaN
# 148                   NaN                   NaN             83.083443
# 149                   NaN                   NaN                   NaN
#
#      2019 Female Literacy  2015 Happiness Score  2016 Happiness Score  \
# 0                     NaN                 3.575                 3.360
# 1                     NaN                 4.959                 4.655
# 2                     NaN                 5.605                 6.355
# 3                     NaN                 4.033                 3.866
# 4                     NaN                 6.574                 6.650
# ..                    ...                   ...                   ...
# 145                   NaN                 6.810                 6.084
# 146                   NaN                 5.360                 5.061
# 147                   NaN                 4.077                 3.724
# 148                   NaN                 5.129                 4.795
# 149                   NaN                 4.610                 4.193
#
#      2017 Happiness Score  2018 Happiness Score  2019 Happiness Score
# 0                   3.794                 3.632                 3.203
# 1                   4.644                 4.586                 4.719
# 2                   5.872                 5.295                 5.211
# 3                   3.795                 3.795                   NaN
# 4                   6.599                 6.388                 6.086
# ..                    ...                   ...                   ...
# 145                 5.250                 4.806                 4.707
# 146                 5.074                 5.103                 5.175
# 147                 3.593                 3.355                 3.380
# 148                 4.514                 4.377                 4.107
# 149                 3.875                 3.692                 3.663
#
# [150 rows x 96 columns]

# %%
# Get rid of NaN values
merged_df.dropna()
merged_df
# Out:
#     Country Name  2015 Total Pop  2016 Total Pop  2017 Total Pop  \
# 0    Afghanistan      34413603.0      35383128.0      36296400.0
# 1        Albania       2880703.0       2876101.0       2873457.0
# 2        Algeria      39728025.0      40551404.0      41389198.0
# 3         Angola      27884381.0      28842484.0      29816748.0
# 4      Argentina      43131966.0      43590368.0      44044811.0
# ..           ...             ...             ...             ...
# 145    Venezuela      30081829.0      29846179.0      29390409.0
# 146      Vietnam      92677076.0      93638724.0      94596642.0
# 147        Yemen      26497889.0      27168210.0      27834821.0
# 148       Zambia      15879361.0      16363507.0      16853688.0
# 149     Zimbabwe      13814629.0      14030390.0      14236745.0
#
#      2018 Total Pop  2019 Total Pop  2015 Adults (%)  2016 Adults (%)  \
# 0        37172386.0      38041754.0        52.644299        53.207964
# 1         2866376.0       2854191.0        68.704725        68.660092
# 2        42228429.0      43053054.0        65.428845        64.857566
# 3        30809762.0      31825295.0        50.615167        50.685629
# 4        44494502.0      44938712.0        64.060020        64.060567
# ..              ...             ...              ...              ...
# 145      28870195.0      28515829.0        65.254716        65.139208
# 146      95540395.0      96462106.0        70.311813        70.138340
# 147      28498687.0      29161922.0        56.512238        56.810155
# 148      17351822.0      17861030.0        51.758764        52.090970
# 149      14439018.0      14645468.0        54.603457        54.473134
#
#      2017 Adults (%)  2018 Adults (%)  ...  2015 Female Literacy  \
# 0          53.763223        54.324898  ...                   NaN
# 1          68.642614        68.582390  ...                   NaN
# 2          64.183205        63.488825  ...                   NaN
# 3          50.807787        50.974702  ...                   NaN
# 4          64.083523        64.121277  ...             99.208771
# ..               ...              ...  ...                   ...
# 145        65.085698        65.066363  ...                   NaN
# 146        69.871421        69.552345  ...                   NaN
# 147        57.146968        57.508840  ...                   NaN
# 148        52.503824        52.964181  ...                   NaN
# 149        54.505941        54.659410  ...                   NaN
#
#      2016 Female Literacy  2017 Female Literacy  2018 Female Literacy  \
# 0                     NaN                   NaN             29.805210
# 1                     NaN                   NaN             97.761124
# 2                     NaN                   NaN             75.322968
# 3                     NaN                   NaN                   NaN
# 4               99.143097                   NaN             99.062042
# ..                    ...                   ...                   ...
# 145                   NaN                   NaN                   NaN
# 146                   NaN                   NaN             93.596710
# 147                   NaN                   NaN                   NaN
# 148                   NaN                   NaN             83.083443
# 149                   NaN                   NaN                   NaN
#
#      2019 Female Literacy  2015 Happiness Score  2016 Happiness Score  \
# 0                     NaN                 3.575                 3.360
# 1                     NaN                 4.959                 4.655
# 2                     NaN                 5.605                 6.355
# 3                     NaN                 4.033                 3.866
# 4                     NaN                 6.574                 6.650
# ..                    ...                   ...                   ...
# 145                   NaN                 6.810                 6.084
# 146                   NaN                 5.360                 5.061
# 147                   NaN                 4.077                 3.724
# 148                   NaN                 5.129                 4.795
# 149                   NaN                 4.610                 4.193
#
#      2017 Happiness Score  2018 Happiness Score  2019 Happiness Score
# 0                   3.794                 3.632                 3.203
# 1                   4.644                 4.586                 4.719
# 2                   5.872                 5.295                 5.211
# 3                   3.795                 3.795                   NaN
# 4                   6.599                 6.388                 6.086
# ..                    ...                   ...                   ...
# 145                 5.250                 4.806                 4.707
# 146                 5.074                 5.103                 5.175
# 147                 3.593                 3.355                 3.380
# 148                 4.514                 4.377                 4.107
# 149                 3.875                 3.692                 3.663
#
# [150 rows x 96 columns]

# %% [markdown]
# ## Let's start plotting!
# ### Total Pop and World Happiness

# %%
# 2015 Total Pop and 2015 World Happiness
plt.scatter(merged_df['2015 Happiness Score'], merged_df['2015 Total Pop'])
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Population')
plt.title('2015 Happiness Scores and Total Population')
plt.show()

# %%
# 2016 Total Pop and 2016 World Happiness
plt.scatter(merged_df['2016 Happiness Score'], merged_df['2016 Total Pop'])
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Population')
plt.title('2016 Happiness Scores and Total Population')
plt.show()

# %%
# 2017 Total Pop and 2017 World Happiness
plt.scatter(merged_df['2017 Happiness Score'], merged_df['2017 Total Pop'])
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Population')
plt.title('2017 Happiness Scores and Total Population')
plt.show()

# %%
# 2018 Total Pop and 2018 World Happiness
plt.scatter(merged_df['2018 Happiness Score'], merged_df['2018 Total Pop'])
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Population')
plt.title('2018 Happiness Scores and Total Population')
plt.show()

# %%
# 2019 Total Pop and 2019 World Happiness
plt.scatter(merged_df['2019 Happiness Score'], merged_df['2019 Total Pop'])
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Population')
plt.title('2019 Happiness Scores and Total Population')
plt.show()

# %% [markdown]
# ### Adult Pop and World Happiness

# %%
# 2015 Adult Pop and 2015 World Happiness

# adults_2015 = merged_df.iloc[:, 6]
# whs_2015 = merged_df.iloc[:, 91]
# pop_whs_2015 = st.pearsonr(adults_2015, whs_2015)
# print(f'The correlation between total population and world happiness score in 2015 is {round(pop_whs_2015[0],2)}.')


# xValues = capDf['Weight (g)']
# yValues = capDf['Tumor Volume (mm3)']
# slope, intercept, rvalue, pvalue, stderr = linregress(xValues, yValues)
# regressValues = xValues * slope + intercept
# lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plt.scatter(xValues,yValues)
# plt.plot(xValues,regressValues,"r-")
# plt.annotate(lineEq,(6,10),fontsize=15,color="red")
# plt.xlabel('Mouse Weight (g)')
# plt.ylabel('Tumor Volume (mm3)')
# plt.title('Mouse Weight and Average Tumor Volume: A Linear Regression')
# plt.show()


# x_adults = merged_df['2015 Happiness Score']
# y_adults = merged_df['2015 Adults (%)']
# slope, intercept, rvalue, pvalue, stderr = linregress(x_adults, y_adults)
# regressValues = x_adults * slope + intercept
# lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# plt.scatter(x_adults, y_adults)
# plt.plot(x_adults,regressValues,"r-")
# plt.annotate(lineEq,(6,10),fontsize=15,color="red")
# plt.xlabel('2015 Happiness Score')
# plt.ylabel('2015 Total Adults (%)')
# plt.title('2015 Happiness Scores and Total Adults (%)')
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-95e3c2281078> in <module>
#       3 adults_2015 = merged_df.iloc[:, 6]
#       4 whs_2015 = merged_df.iloc[:, 91]
# ----> 5 pop_whs_2015 = st.pearsonr(adults_2015, whs_2015)
#       6 print(f'The correlation between total population and world happiness score in 2015 is {round(pop_whs_2015[0],2)}.')
#       7
#
# ~\anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3865     # scipy.linalg.norm(xm) does not overflow if xm is, for example,
#    3866     # [-5e210, 5e210, 3e200, -3e200]
# -> 3867     normxm = linalg.norm(xm)
#    3868     normym = linalg.norm(ym)
#    3869
#
# ~\anaconda3\lib\site-packages\scipy\linalg\misc.py in norm(a, ord, axis, keepdims, check_finite)
#     138     # Differs from numpy only in non-finite handling and the use of blas.
#     139     if check_finite:
# --> 140         a = np.asarray_chkfinite(a)
#     141     else:
#     142         a = np.asarray(a)
#
# ~\anaconda3\lib\site-packages\numpy\lib\function_base.py in asarray_chkfinite(a, dtype, order)
#     483     a = asarray(a, dtype=dtype, order=order)
#     484     if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 485         raise ValueError(
#     486             "array must not contain infs or NaNs")
#     487     return a
#
# ValueError: array must not contain infs or NaNs
