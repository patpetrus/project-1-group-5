# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import sem
from scipy.stats import linregress

# %%
# Set path and read CSV
path = '../ocean_data/final2_merge.csv'
merged_df = pd.read_csv(path)
merged_df
# Out:
#       Country Name  2015 Total Pop  2016 Total Pop  2017 Total Pop  \
# 0      Afghanistan      34413603.0      35383128.0      36296400.0
# 1          Albania       2880703.0       2876101.0       2873457.0
# 2        Argentina      43131966.0      43590368.0      44044811.0
# 3          Armenia       2925553.0       2936146.0       2944809.0
# 4        Australia      23815995.0      24190907.0      24601860.0
# ..             ...             ...             ...             ...
# 113        Uruguay       3412009.0       3424132.0       3436646.0
# 114  United States     320635163.0     322941311.0     324985539.0
# 115   South Africa      55386367.0      56203654.0      57000451.0
# 116         Zambia      15879361.0      16363507.0      16853688.0
# 117       Zimbabwe      13814629.0      14030390.0      14236745.0
#
#      2018 Total Pop  2019 Total Pop  2015 Adults (%)  2016 Adults (%)  \
# 0        37172386.0      38041754.0        52.644299        53.207964
# ...

# %% [markdown]
# # Let's start plotting!
# ## Total Pop and World Happiness

# %%
# 2015 Total Pop and 2015 World Happiness
plt.scatter(merged_df['2015 Happiness Score'], merged_df['2015 Total Pop'])
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Population')
plt.title('2015 Happiness Scores and Total Population')
plt.show()

# %%
# 2016 Total Pop and 2016 World Happiness
plt.scatter(merged_df['2016 Happiness Score'], merged_df['2016 Total Pop'])
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Population')
plt.title('2016 Happiness Scores and Total Population')
plt.show()

# %%
# 2017 Total Pop and 2017 World Happiness
plt.scatter(merged_df['2017 Happiness Score'], merged_df['2017 Total Pop'])
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Population')
plt.title('2017 Happiness Scores and Total Population')
plt.show()

# %%
# 2018 Total Pop and 2018 World Happiness
plt.scatter(merged_df['2018 Happiness Score'], merged_df['2018 Total Pop'])
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Population')
plt.title('2018 Happiness Scores and Total Population')
plt.show()

# %%
# 2019 Total Pop and 2019 World Happiness
plt.scatter(merged_df['2019 Happiness Score'], merged_df['2019 Total Pop'])
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Population')
plt.title('2019 Happiness Scores and Total Population')
plt.show()

# %% [markdown]
# ## Adult Pop and World Happiness

# %%
# 2015 Adult Pop and 2015 World Happiness

adults_2015 = merged_df.iloc[:, 6]
whs_2015 = merged_df.iloc[:, 58]
pop_whs_2015 = st.pearsonr(adults_2015, whs_2015)
print(f'The correlation between total population and world happiness score in 2015 is {round(pop_whs_2015[0],2)}.')

x_adults_2015 = merged_df['2015 Happiness Score']
y_adults_2015 = merged_df['2015 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2015, y_adults_2015)
regressValues = x_adults_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2015, y_adults_2015)
plt.plot(x_adults_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Adults (%)')
plt.title('2015 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2015 is 0.57.

# %%
# 2016 Adult Pop and 2016 World Happiness

adults_2016 = merged_df.iloc[:, 7]
whs_2016 = merged_df.iloc[:, 59]
pop_whs_2016 = st.pearsonr(adults_2016, whs_2016)
print(f'The correlation between total population and world happiness score in 2016 is {round(pop_whs_2016[0],2)}.')

x_adults_2016 = merged_df['2016 Happiness Score']
y_adults_2016 = merged_df['2016 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2016, y_adults_2016)
regressValues = x_adults_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2016, y_adults_2016)
plt.plot(x_adults_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Adults (%)')
plt.title('2016 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2016 is 0.59.

# %%
# 2017 Adult Pop and 2017 World Happiness

adults_2017 = merged_df.iloc[:, 8]
whs_2017 = merged_df.iloc[:, 60]
pop_whs_2017 = st.pearsonr(adults_2017, whs_2017)
print(f'The correlation between total population and world happiness score in 2017 is {round(pop_whs_2017[0],2)}.')

x_adults_2017 = merged_df['2017 Happiness Score']
y_adults_2017 = merged_df['2017 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2017, y_adults_2017)
regressValues = x_adults_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2017, y_adults_2017)
plt.plot(x_adults_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Adults (%)')
plt.title('2017 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2017 is 0.57.

# %%
# 2018 Adult Pop and 2018 World Happiness

adults_2018 = merged_df.iloc[:, 9]
whs_2018 = merged_df.iloc[:, 61]
pop_whs_2018 = st.pearsonr(adults_2018, whs_2018)
print(f'The correlation between total population and world happiness score in 2018 is {round(pop_whs_2018[0],2)}.')

x_adults_2018 = merged_df['2018 Happiness Score']
y_adults_2018 = merged_df['2018 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2018, y_adults_2018)
regressValues = x_adults_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2018, y_adults_2018)
plt.plot(x_adults_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Adults (%)')
plt.title('2018 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2018 is 0.54.

# %%
# 2019 Adult Pop and 2019 World Happiness

adults_2019 = merged_df.iloc[:, 10]
whs_2019 = merged_df.iloc[:, 62]
pop_whs_2019 = st.pearsonr(adults_2019, whs_2019)
print(f'The correlation between total population and world happiness score in 2019 is {round(pop_whs_2019[0],2)}.')

x_adults_2019 = merged_df['2019 Happiness Score']
y_adults_2019 = merged_df['2019 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2019, y_adults_2019)
regressValues = x_adults_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2019, y_adults_2019)
plt.plot(x_adults_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Adults (%)')
plt.title('2019 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2019 is 0.5.

# %% [markdown]
# ## Total Unemployment and World Happiness

# %%
# 2015 Total Unemployment and 2015 World Happiness
plt.scatter(merged_df['2015 Happiness Score'], merged_df['2015 Total Unemploment'])
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Unemployment')
plt.title('2015 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2015 Total Unemployment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-f828b8c7b08d> in <module>
# ...
