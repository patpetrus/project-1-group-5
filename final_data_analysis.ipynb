# %% [markdown]
# # Final Data Analysis

# %%
# Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
from scipy.stats import sem
from scipy.stats import linregress

# %%
# Set path and read CSV
path = 'ocean_data/MERGE.csv'
merged_df = pd.read_csv(path)
merged_df
# Out:
#       Country Name  2015 Total Pop  2016 Total Pop  2017 Total Pop  \
# 0      Afghanistan      34413603.0      35383128.0      36296400.0
# 1          Albania       2880703.0       2876101.0       2873457.0
# 2        Argentina      43131966.0      43590368.0      44044811.0
# 3          Armenia       2925553.0       2936146.0       2944809.0
# 4        Australia      23815995.0      24190907.0      24601860.0
# ..             ...             ...             ...             ...
# 113        Uruguay       3412009.0       3424132.0       3436646.0
# 114  United States     320635163.0     322941311.0     324985539.0
# 115   South Africa      55386367.0      56203654.0      57000451.0
# 116         Zambia      15879361.0      16363507.0      16853688.0
# 117       Zimbabwe      13814629.0      14030390.0      14236745.0
#
#      2018 Total Pop  2019 Total Pop  2015 Adults (%)  2016 Adults (%)  \
# 0        37172386.0      38041754.0        52.644299        53.207964
# ...

# %% [markdown]
# # Let's start plotting!
# ## Total Pop and World Happiness Score

# %%
# 2015 Total Pop and 2015 World Happiness

total_2015 = merged_df.iloc[:, 1]
whs_2015 = merged_df.iloc[:, 58]
total_whs_2015 = st.pearsonr(total_2015, whs_2015)
print(f'The correlation between total population and world happiness score in 2015 is {round(total_whs_2015[0],2)}.')

x_total_2015 = merged_df['2015 Happiness Score']
y_total_2015 = merged_df['2015 Total Pop']
slope, intercept, rvalue, pvalue, stderr = linregress(x_total_2015, y_total_2015)
regressValues = x_total_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_total_2015, y_total_2015)
plt.plot(x_total_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Population')
plt.title('2015 Happiness Scores and Total Population')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2015 is -0.04.

# %%
# 2016 Total Pop and 2016 World Happiness

total_2016 = merged_df.iloc[:, 2]
whs_2016 = merged_df.iloc[:, 59]
total_whs_2016 = st.pearsonr(total_2016, whs_2016)
print(f'The correlation between total population and world happiness score in 2016 is {round(total_whs_2016[0],2)}.')

x_total_2016 = merged_df['2016 Happiness Score']
y_total_2016 = merged_df['2016 Total Pop']
slope, intercept, rvalue, pvalue, stderr = linregress(x_total_2016, y_total_2016)
regressValues = x_total_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_total_2016, y_total_2016)
plt.plot(x_total_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Population')
plt.title('2016 Happiness Scores and Total Population')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2016 is -0.05.

# %%
# 2017 Total Pop and 2017 World Happiness

total_2017 = merged_df.iloc[:, 3]
whs_2017 = merged_df.iloc[:, 60]
total_whs_2017 = st.pearsonr(total_2017, whs_2017)
print(f'The correlation between total population and world happiness score in 2017 is {round(total_whs_2017[0],2)}.')

x_total_2017 = merged_df['2017 Happiness Score']
y_total_2017 = merged_df['2017 Total Pop']
slope, intercept, rvalue, pvalue, stderr = linregress(x_total_2017, y_total_2017)
regressValues = x_total_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_total_2017, y_total_2017)
plt.plot(x_total_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Population')
plt.title('2017 Happiness Scores and Total Population')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2017 is -0.06.

# %%
# 2018 Total Pop and 2018 World Happiness

total_2018 = merged_df.iloc[:, 4]
whs_2018 = merged_df.iloc[:, 61]
total_whs_2018 = st.pearsonr(total_2018, whs_2018)
print(f'The correlation between total population and world happiness score in 2018is {round(total_whs_2018[0],2)}')

x_total_2018= merged_df['2018 Happiness Score']
y_total_2018= merged_df['2018 Total Pop']
slope, intercept, rvalue, pvalue, stderr = linregress(x_total_2018,y_total_2018)
regressValues = x_total_2018* slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_total_2018,y_total_2018)
plt.plot(x_total_2018,regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Population')
plt.title('2018 Happiness Scores and Total Population')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2018is -0.08

# %%
# 2019 Total Pop and 2019 World Happiness

total_2019 = merged_df.iloc[:, 5]
whs_2019 = merged_df.iloc[:, 62]
total_whs_2019 = st.pearsonr(total_2019, whs_2019)
print(f'The correlation between total population and world happiness score in 2019 is {round(total_whs_2019[0],2)}')

x_total_2019= merged_df['2019 Happiness Score']
y_total_2019= merged_df['2019 Total Pop']
slope, intercept, rvalue, pvalue, stderr = linregress(x_total_2019,y_total_2019)
regressValues = x_total_2019* slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_total_2019,y_total_2019)
plt.plot(x_total_2019,regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Population')
plt.title('2019 Happiness Scores and Total Population')
plt.show()
# Out:
# The correlation between total population and world happiness score in 2019 is -0.1

# %% [markdown]
# ## Adult Pop and World Happiness Score

# %%
# 2015 Adult Pop and 2015 World Happiness

adults_2015 = merged_df.iloc[:, 6]
whs_2015 = merged_df.iloc[:, 58]
pop_whs_2015 = st.pearsonr(adults_2015, whs_2015)
print(f'The correlation between adult population and world happiness score in 2015 is {round(pop_whs_2015[0],2)}.')

x_adults_2015 = merged_df['2015 Happiness Score']
y_adults_2015 = merged_df['2015 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2015, y_adults_2015)
regressValues = x_adults_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2015, y_adults_2015)
plt.plot(x_adults_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Adults (%)')
plt.title('2015 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between adult population and world happiness score in 2015 is 0.57.

# %%
# 2016 Adult Pop and 2016 World Happiness

adults_2016 = merged_df.iloc[:, 7]
whs_2016 = merged_df.iloc[:, 59]
pop_whs_2016 = st.pearsonr(adults_2016, whs_2016)
print(f'The correlation between adult population and world happiness score in 2016 is {round(pop_whs_2016[0],2)}.')

x_adults_2016 = merged_df['2016 Happiness Score']
y_adults_2016 = merged_df['2016 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2016, y_adults_2016)
regressValues = x_adults_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2016, y_adults_2016)
plt.plot(x_adults_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Adults (%)')
plt.title('2016 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between adult population and world happiness score in 2016 is 0.59.

# %%
# 2017 Adult Pop and 2017 World Happiness

adults_2017 = merged_df.iloc[:, 8]
whs_2017 = merged_df.iloc[:, 60]
pop_whs_2017 = st.pearsonr(adults_2017, whs_2017)
print(f'The correlation between adult population and world happiness score in 2017 is {round(pop_whs_2017[0],2)}.')

x_adults_2017 = merged_df['2017 Happiness Score']
y_adults_2017 = merged_df['2017 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2017, y_adults_2017)
regressValues = x_adults_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2017, y_adults_2017)
plt.plot(x_adults_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Adults (%)')
plt.title('2017 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between adult population and world happiness score in 2017 is 0.57.

# %%
# 2018 Adult Pop and 2018 World Happiness

adults_2018 = merged_df.iloc[:, 9]
whs_2018 = merged_df.iloc[:, 61]
pop_whs_2018 = st.pearsonr(adults_2018, whs_2018)
print(f'The correlation between adult population and world happiness score in 2018 is {round(pop_whs_2018[0],2)}.')

x_adults_2018 = merged_df['2018 Happiness Score']
y_adults_2018 = merged_df['2018 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2018, y_adults_2018)
regressValues = x_adults_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2018, y_adults_2018)
plt.plot(x_adults_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Adults (%)')
plt.title('2018 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between adult population and world happiness score in 2018 is 0.54.

# %%
# 2019 Adult Pop and 2019 World Happiness

adults_2019 = merged_df.iloc[:, 10]
whs_2019 = merged_df.iloc[:, 62]
pop_whs_2019 = st.pearsonr(adults_2019, whs_2019)
print(f'The correlation between adult population and world happiness score in 2019 is {round(pop_whs_2019[0],2)}.')

x_adults_2019 = merged_df['2019 Happiness Score']
y_adults_2019 = merged_df['2019 Adults (%)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2019, y_adults_2019)
regressValues = x_adults_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2019, y_adults_2019)
plt.plot(x_adults_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Adults (%)')
plt.title('2019 Happiness Scores and Total Adults (%)')
plt.show()
# Out:
# The correlation between adult population and world happiness score in 2019 is 0.5.

# %% [markdown]
# ## Total Unemployment and World Happiness Score

# %%
# 2015 Total Unemployment and 2015 World Happiness

unemploy_2015 = merged_df.iloc[:, 11]
whs_2015 = merged_df.iloc[:, 58]
unemploy_whs_2015 = st.pearsonr(unemploy_2015, whs_2015)
print(f'The correlation between total unemployment and world happiness score in 2015 is {round(unemploy_whs_2015[0],2)}.')

x_unemploy_2015 = merged_df['2015 Happiness Score']
y_unemploy_2015 = merged_df['2015 Total Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_unemploy_2015, y_unemploy_2015)
regressValues = x_unemploy_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_unemploy_2015, y_unemploy_2015)
plt.plot(x_unemploy_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Unemployment')
plt.title('2015 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2015 is -0.05.

# %%
# 2016 Total Unemployment and 2016 World Happiness

unemploy_2016 = merged_df.iloc[:, 12]
whs_2016 = merged_df.iloc[:, 59]
unemploy_whs_2016 = st.pearsonr(unemploy_2016, whs_2016)
print(f'The correlation between total unemployment and world happiness score in 2016 is {round(unemploy_whs_2016[0],2)}.')

x_unemploy_2016 = merged_df['2016 Happiness Score']
y_unemploy_2016 = merged_df['2016 Total Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_unemploy_2016, y_unemploy_2016)
regressValues = x_unemploy_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_unemploy_2016, y_unemploy_2016)
plt.plot(x_unemploy_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Unemployment')
plt.title('2016 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2016 is -0.07.

# %%
# 2017 Total Unemployment and 2017 World Happiness

unemploy_2017 = merged_df.iloc[:, 13]
whs_2017 = merged_df.iloc[:, 60]
unemploy_whs_2017 = st.pearsonr(unemploy_2017, whs_2017)
print(f'The correlation between total unemployment and world happiness score in 2017 is {round(unemploy_whs_2017[0],2)}.')

x_unemploy_2017 = merged_df['2017 Happiness Score']
y_unemploy_2017 = merged_df['2017 Total Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_unemploy_2017, y_unemploy_2017)
regressValues = x_unemploy_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_unemploy_2017, y_unemploy_2017)
plt.plot(x_unemploy_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Unemployment')
plt.title('2017 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2017 is -0.09.

# %%
# 2018 Total Unemployment and 2018 World Happiness

unemploy_2018 = merged_df.iloc[:, 14]
whs_2018 = merged_df.iloc[:, 61]
unemploy_whs_2018 = st.pearsonr(unemploy_2018, whs_2018)
print(f'The correlation between total unemployment and world happiness score in 2018 is {round(unemploy_whs_2018[0],2)}.')

x_unemploy_2018 = merged_df['2018 Happiness Score']
y_unemploy_2018 = merged_df['2018 Total Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_unemploy_2018, y_unemploy_2018)
regressValues = x_unemploy_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_unemploy_2018, y_unemploy_2018)
plt.plot(x_unemploy_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Unemployment')
plt.title('2018 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2018 is -0.14.

# %%
# 2019 Total Unemployment and 2019 World Happiness

unemploy_2019 = merged_df.iloc[:, 15]
whs_2019 = merged_df.iloc[:, 62]
unemploy_whs_2019 = st.pearsonr(unemploy_2019, whs_2019)
print(f'The correlation between total unemployment and world happiness score in 2019 is {round(unemploy_whs_2019[0],2)}.')

x_unemploy_2019 = merged_df['2019 Happiness Score']
y_unemploy_2019 = merged_df['2019 Total Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_unemploy_2019, y_unemploy_2019)
regressValues = x_unemploy_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_unemploy_2019, y_unemploy_2019)
plt.plot(x_unemploy_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Unemployment')
plt.title('2019 Happiness Scores and Total Unemployment')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2019 is -0.17.

# %% [markdown]
# ## Female Unemployment and World Happiness Score

# %%
# 2015 Female Unemployment and 2015 World Happiness

f_unemploy_2015 = merged_df.iloc[:, 16]
whs_2015 = merged_df.iloc[:, 58]
f_unemploy_whs_2015 = st.pearsonr(f_unemploy_2015, whs_2015)
print(f'The correlation between female unemployment and world happiness score in 2015 is {round(f_unemploy_whs_2015[0],2)}.')

x_whs_2015 = merged_df['2015 Happiness Score']
y_f_unemploy_2015 = merged_df['2015 Female Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2015, y_f_unemploy_2015)
regressValues = x_whs_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2015, y_f_unemploy_2015)
plt.plot(x_whs_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Female Unemployment')
plt.title('2015 Happiness Scores and Female Unemployment')
plt.show()
# Out:
# The correlation between female unemployment and world happiness score in 2015 is -0.08.

# %%
# 2016 Female Unemployment and 2016 World Happiness

f_unemploy_2016 = merged_df.iloc[:, 17]
whs_2016 = merged_df.iloc[:, 59]
f_unemploy_whs_2016 = st.pearsonr(f_unemploy_2016, whs_2016)
print(f'The correlation between female unemployment and world happiness score in 2016 is {round(f_unemploy_whs_2016[0],2)}.')

x_whs_2016 = merged_df['2016 Happiness Score']
y_f_unemploy_2016 = merged_df['2016 Female Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2016, y_f_unemploy_2016)
regressValues = x_whs_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2016, y_f_unemploy_2016)
plt.plot(x_whs_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Female Unemployment')
plt.title('2016 Happiness Scores and Female Unemployment')
plt.show()
# Out:
# The correlation between female unemployment and world happiness score in 2016 is -0.08.

# %%
# 2017 Female Unemployment and 2017 World Happiness

f_unemploy_2017 = merged_df.iloc[:, 18]
whs_2017 = merged_df.iloc[:, 60]
f_unemploy_whs_2017 = st.pearsonr(f_unemploy_2017, whs_2017)
print(f'The correlation between female unemployment and world happiness score in 2017 is {round(f_unemploy_whs_2017[0],2)}.')

x_whs_2017 = merged_df['2017 Happiness Score']
y_f_unemploy_2017 = merged_df['2017 Female Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2017, y_f_unemploy_2017)
regressValues = x_whs_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2017, y_f_unemploy_2017)
plt.plot(x_whs_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Female Unemployment')
plt.title('2017 Happiness Scores and Female Unemployment')
plt.show()
# Out:
# The correlation between female unemployment and world happiness score in 2017 is -0.1.

# %%
# 2018 Female Unemployment and 2018 World Happiness

f_unemploy_2018 = merged_df.iloc[:, 19]
whs_2018 = merged_df.iloc[:, 61]
f_unemploy_whs_2018 = st.pearsonr(f_unemploy_2018, whs_2018)
print(f'The correlation between female unemployment and world happiness score in 2018 is {round(f_unemploy_whs_2018[0],2)}.')

x_whs_2018 = merged_df['2018 Happiness Score']
y_f_unemploy_2018 = merged_df['2018 Female Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2018, y_f_unemploy_2018)
regressValues = x_whs_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2018, y_f_unemploy_2018)
plt.plot(x_whs_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Female Unemployment')
plt.title('2018 Happiness Scores and Female Unemployment')
plt.show()
# Out:
# The correlation between female unemployment and world happiness score in 2018 is -0.14.

# %%
# 2019 Female Unemployment and 2019 World Happiness

f_unemploy_2019 = merged_df.iloc[:, 20]
whs_2019 = merged_df.iloc[:, 62]
f_unemploy_whs_2019 = st.pearsonr(f_unemploy_2019, whs_2019)
print(f'The correlation between female unemployment and world happiness score in 2019 is {round(f_unemploy_whs_2019[0],2)}.')

x_whs_2019 = merged_df['2019 Happiness Score']
y_f_unemploy_2019 = merged_df['2019 Female Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2019, y_f_unemploy_2019)
regressValues = x_whs_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2019, y_f_unemploy_2019)
plt.plot(x_whs_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Female Unemployment')
plt.title('2019 Happiness Scores and Female Unemployment')
plt.show()
# Out:
# The correlation between female unemployment and world happiness score in 2019 is -0.18.

# %% [markdown]
# ## Male Unemployment and World Happiness Score

# %%
# 2015 Male Unemployment and 2015 World Happiness 

m_unemploy_2015 = merged_df.iloc[:, 21]
whs_2015 = merged_df.iloc[:, 58]
m_unemploy_whs_2015 = st.pearsonr(m_unemploy_2015, whs_2015)
print(f'The correlation between male unemployment and world happiness score in 2015 is {round(m_unemploy_whs_2015[0],2)}.')

x_whs_2015 = merged_df['2015 Happiness Score']
y_m_unemploy_2015 = merged_df['2015 Male Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2015, y_m_unemploy_2015)
regressValues = x_whs_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2015, y_m_unemploy_2015)
plt.plot(x_whs_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Male Unemployment')
plt.title('2015 Happiness Scores and Male Unemployment')
plt.show()
# Out:
# The correlation between male unemployment and world happiness score in 2015 is -0.03.

# %%
# 2016 Male Unemployment and 2016 World Happiness 

m_unemploy_2016 = merged_df.iloc[:, 22]
whs_2016 = merged_df.iloc[:, 59]
m_unemploy_whs_2016 = st.pearsonr(m_unemploy_2016, whs_2016)
print(f'The correlation between male unemployment and world happiness score in 2016 is {round(m_unemploy_whs_2016[0],2)}.')

x_whs_2016 = merged_df['2016 Happiness Score']
y_m_unemploy_2016 = merged_df['2016 Male Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2016, y_m_unemploy_2016)
regressValues = x_whs_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2016, y_m_unemploy_2016)
plt.plot(x_whs_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Male Unemployment')
plt.title('2016 Happiness Scores and Male Unemployment')
plt.show()
# Out:
# The correlation between male unemployment and world happiness score in 2016 is -0.06.

# %%
# 2017 Male Unemployment and 2017 World Happiness 

m_unemploy_2017 = merged_df.iloc[:, 23]
whs_2017 = merged_df.iloc[:, 60]
m_unemploy_whs_2017 = st.pearsonr(m_unemploy_2017, whs_2017)
print(f'The correlation between male unemployment and world happiness score in 2017 is {round(m_unemploy_whs_2017[0],2)}.')

x_whs_2017 = merged_df['2017 Happiness Score']
y_m_unemploy_2017 = merged_df['2017 Male Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2017, y_m_unemploy_2017)
regressValues = x_whs_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2017, y_m_unemploy_2017)
plt.plot(x_whs_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Male Unemployment')
plt.title('2017 Happiness Scores and Male Unemployment')
plt.show()
# Out:
# The correlation between male unemployment and world happiness score in 2017 is -0.07.

# %%
# 2018 Male Unemployment and 2018 World Happiness 

m_unemploy_2018 = merged_df.iloc[:, 24]
whs_2018 = merged_df.iloc[:, 61]
m_unemploy_whs_2018 = st.pearsonr(m_unemploy_2018, whs_2018)
print(f'The correlation between male unemployment and world happiness score in 2018 is {round(m_unemploy_whs_2018[0],2)}.')

x_whs_2018 = merged_df['2018 Happiness Score']
y_m_unemploy_2018 = merged_df['2018 Male Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2018, y_m_unemploy_2018)
regressValues = x_whs_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2018, y_m_unemploy_2018)
plt.plot(x_whs_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Male Unemployment')
plt.title('2018 Happiness Scores and Male Unemployment')
plt.show()
# Out:
# The correlation between male unemployment and world happiness score in 2018 is -0.13.

# %%
# 2019 Male Unemployment and 2019 World Happiness 

m_unemploy_2019 = merged_df.iloc[:, 25]
whs_2019 = merged_df.iloc[:, 62]
m_unemploy_whs_2019 = st.pearsonr(m_unemploy_2019, whs_2019)
print(f'The correlation between male unemployment and world happiness score in 2019 is {round(m_unemploy_whs_2019[0],2)}.')

x_whs_2019 = merged_df['2019 Happiness Score']
y_m_unemploy_2019 = merged_df['2019 Male Unemployment']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2019, y_m_unemploy_2019)
regressValues = x_whs_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2019, y_m_unemploy_2019)
plt.plot(x_whs_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Male Unemployment')
plt.title('2019 Happiness Scores and Male Unemployment')
plt.show()
# Out:
# The correlation between male unemployment and world happiness score in 2019 is -0.16.

# %% [markdown]
# ## Military Expenditure/ % GDP and World Happiness Score

# %%
# 2015 Total % of Military Expenditure and 2015 World Happiness

military_2015 = merged_df.iloc[:, 44]
whs_2015 = merged_df.iloc[:, 58]
mil_whs_2015 = st.pearsonr(military_2015, whs_2015)
print(f'The correlation between total military expenditure and world happiness score in 2015 is {round(mil_whs_2015[0],2)}.')

x_adults_2015 = merged_df['2015 Happiness Score']
y_adults_2015 = merged_df['2015 Military Expenditure (%GDP)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2015, y_adults_2015)
regressValues = x_adults_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2015, y_adults_2015)
plt.plot(x_adults_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Military Expenditure (%GDP)')
plt.title('2015 Happiness Scores and Total Military Expenditure (%GDP)')
plt.show()
# Out:
# The correlation between total military expenditure and world happiness score in 2015 is -0.2.

# %%
# 2016 Total % of Military Expenditure and 2016 World Happiness

military_2016 = merged_df.iloc[:, 45]
whs_2016 = merged_df.iloc[:, 59]
mil_whs_2016 = st.pearsonr(military_2016, whs_2016)
print(f'The correlation between total military expenditure and world happiness score in 2016 is {round(mil_whs_2016[0],2)}.')

x_adults_2016 = merged_df['2016 Happiness Score']
y_adults_2016 = merged_df['2016 Military Expenditure (%GDP)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2016, y_adults_2016)
regressValues = x_adults_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2016, y_adults_2016)
plt.plot(x_adults_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Military Expenditure (%GDP)')
plt.title('2016 Happiness Scores and Total Military Expenditure (%GDP)')
plt.show()
# Out:
# The correlation between total military expenditure and world happiness score in 2016 is -0.15.

# %%
# 2017 Total % of Military Expenditure and 2017 World Happiness

military_2017 = merged_df.iloc[:, 46]
whs_2017 = merged_df.iloc[:, 60]
mil_whs_2017 = st.pearsonr(military_2017, whs_2017)
print(f'The correlation between total military expenditure and world happiness score in 2017 is {round(mil_whs_2017[0],2)}.')

x_adults_2017 = merged_df['2017 Happiness Score']
y_adults_2017 = merged_df['2017 Military Expenditure (%GDP)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2017, y_adults_2017)
regressValues = x_adults_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2017, y_adults_2017)
plt.plot(x_adults_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Military Expenditure (%GDP)')
plt.title('2017 Happiness Scores and Total Military Expenditure (%GDP)')
plt.show()
# Out:
# The correlation between total military expenditure and world happiness score in 2017 is -0.19.

# %%
# 2018 Total % of Military Expenditure and 2018 World Happiness

military_2018 = merged_df.iloc[:, 47]
whs_2018 = merged_df.iloc[:, 61]
mil_whs_2018 = st.pearsonr(military_2018, whs_2018)
print(f'The correlation between total military expenditure and world happiness score in 2018 is {round(mil_whs_2018[0],2)}.')

x_adults_2018 = merged_df['2018 Happiness Score']
y_adults_2018 = merged_df[' 2018 Military Expenditure (%GDP)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2018, y_adults_2018)
regressValues = x_adults_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2018, y_adults_2018)
plt.plot(x_adults_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel(' 2018 Military Expenditure (%GDP)')
plt.title('2018 Happiness Scores and Total Military Expenditure (%GDP)')
plt.show()
# Out:
# The correlation between total military expenditure and world happiness score in 2018 is -0.21.

# %%
# 2019 Total % of Military Expenditure and 2019 World Happiness

military_2019 = merged_df.iloc[:, 46]
whs_2019 = merged_df.iloc[:, 62]
mil_whs_2019 = st.pearsonr(military_2019, whs_2019)
print(f'The correlation between total military expenditure and world happiness score in 2017 is {round(mil_whs_2019[0],2)}.')

x_adults_2019 = merged_df['2019 Happiness Score']
y_adults_2019 = merged_df['2019 Military Expenditure (%GDP)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2019, y_adults_2019)
regressValues = x_adults_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2019, y_adults_2019)
plt.plot(x_adults_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Military Expenditure (%GDP)')
plt.title('2019 Happiness Scores and Total Military Expenditure (%GDP)')
plt.show()
# Out:
# The correlation between total military expenditure and world happiness score in 2017 is -0.22.

# %% [markdown]
# ## Access to Electricty and World Happiness Score

# %%
# 2015 Access to Electricty and 2015 World Happiness

elec_2015 = merged_df.iloc[:, 27]
whs_2015 = merged_df.iloc[:, 58]
elec_whs_2015 = st.pearsonr(elec_2015, whs_2015)
print(f'The correlation between total access to electricity and world happiness score in 2015 is {round(elec_whs_2015[0],2)}.')

x_adults_2015 = merged_df['2015 Happiness Score']
y_adults_2015 = merged_df['2015 Access to Electricity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2015, y_adults_2015)
regressValues = x_adults_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2015, y_adults_2015)
plt.plot(x_adults_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Access to Electricity')
plt.title('2015 Happiness Scores and Access to Electricity')
plt.show()
# Out:
# The correlation between total access to electricity and world happiness score in 2015 is 0.65.

# %%
# 2016 Access to Electricty and 2016 World Happiness

elec_2016 = merged_df.iloc[:, 28]
whs_2016 = merged_df.iloc[:, 59]
elec_whs_2016 = st.pearsonr(elec_2016, whs_2016)
print(f'The correlation between total access to electricity and world happiness score in 2016 is {round(elec_whs_2016[0],2)}.')

x_adults_2016 = merged_df['2016 Happiness Score']
y_adults_2016 = merged_df['2016 Access to Electricity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2016, y_adults_2016)
regressValues = x_adults_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2016, y_adults_2016)
plt.plot(x_adults_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Access to Electricity')
plt.title('2016 Happiness Scores and Access to Electricity')
plt.show()
# Out:
# The correlation between total access to electricity and world happiness score in 2016 is 0.67.

# %%
# 2017 Access to Electricty and 2017 World Happiness

elec_2017 = merged_df.iloc[:, 29]
whs_2017 = merged_df.iloc[:, 60]
elec_whs_2017 = st.pearsonr(elec_2016, whs_2016)
print(f'The correlation between total access to electricity and world happiness score in 2017 is {round(elec_whs_2017[0],2)}.')

x_adults_2017 = merged_df['2017 Happiness Score']
y_adults_2017 = merged_df['2017 Access to Electricity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2017, y_adults_2017)
regressValues = x_adults_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2017, y_adults_2017)
plt.plot(x_adults_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Access to Electricity')
plt.title('2017 Happiness Scores and Access to Electricity')
plt.show()
# Out:
# The correlation between total access to electricity and world happiness score in 2017 is 0.67.

# %%
# 2018 Total % of Military Expenditure and 2018 World Happiness

elec_2018 = merged_df.iloc[:, 30]
whs_2018 = merged_df.iloc[:, 61]
elec_whs_2018 = st.pearsonr(elec_2018, whs_2018)
print(f'The correlation between total access to electricity and world happiness score in 2018 is {round(elec_whs_2018[0],2)}.')

x_adults_2018 = merged_df['2018 Happiness Score']
y_adults_2018 = merged_df['2018 Access to Electricity']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2018, y_adults_2018)
regressValues = x_adults_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2018, y_adults_2018)
plt.plot(x_adults_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Access to Electricity')
plt.title('2018 Happiness Scores and Access to Electricity')
plt.show()
# Out:
# The correlation between total access to electricity and world happiness score in 2018 is -0.66.

# %% [markdown]
# ## Infant Mortality Rate and World Happiness Score

# %%
# 2015 Infant Mortality Rate and 2015 World Happiness

imr_2015 = merged_df.iloc[:, 30]
whs_2015 = merged_df.iloc[:, 58]
imr_whs_2015 = st.pearsonr(imr_2015, whs_2015)
print(f'The correlation between infant mortality and world happiness score in 2015 is {round(imr_whs_2015[0],2)}.')

x_imr_2015 = merged_df['2015 Happiness Score']
y_imr_2015 = merged_df['2015 Mortality (<5)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_imr_2015, y_imr_2015)
regressValues = x_imr_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_imr_2015, y_imr_2015)
plt.plot(x_imr_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Infant Mortality Rate (per 1k)')
plt.title('2015 Happiness Scores and Infant Mortality Rate')
plt.show()
# Out:
# The correlation between infant mortality and world happiness score in 2015 is -0.66.

# %%
# 2016 Infant Mortality and 2016 World Happiness

imr_2016 = merged_df.iloc[:, 31]
whs_2016 = merged_df.iloc[:, 59]
imr_whs_2016 = st.pearsonr(imr_2016, whs_2016)
print(f'The correlation between infant mortality and world happiness score in 2016 is {round(imr_whs_2016[0],2)}.')

x_imr_2016 = merged_df['2016 Happiness Score']
y_imr_2016 = merged_df['2016 Mortality (<5)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_imr_2016, y_imr_2016)
regressValues = x_imr_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_imr_2016, y_imr_2016)
plt.plot(x_imr_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Infant Mortality Rate (per 1k)')
plt.title('2016 Happiness Scores and Infant Mortality Rate (%)')
plt.show()
# Out:
# The correlation between infant mortality and world happiness score in 2016 is -0.69.

# %%
# 2017 Infant Mortality Rate and 2017 World Happiness

imr_2017 = merged_df.iloc[:, 32]
whs_2017 = merged_df.iloc[:, 60]
imr_whs_2017 = st.pearsonr(imr_2017, whs_2017)
print(f'The correlation between infant mortality and world happiness score in 2017 is {round(imr_whs_2017[0],2)}.')

x_imr_2017 = merged_df['2017 Happiness Score']
y_imr_2017 = merged_df['2017 Mortality (<5)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_imr_2017, y_imr_2017)
regressValues = x_imr_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_imr_2017, y_imr_2017)
plt.plot(x_imr_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Infant Mortality Rate (per 1k)')
plt.title('2017 Happiness Scores and Infant Mortality Rate (%)')
plt.show()
# Out:
# The correlation between infant mortality and world happiness score in 2017 is -0.68.

# %%
# 2018 Infant Mortality Rate and 2018 World Happiness

adults_2018 = merged_df.iloc[:, 33]
whs_2018 = merged_df.iloc[:, 61]
pop_whs_2018 = st.pearsonr(adults_2018, whs_2018)
print(f'The correlation between infant mortality and world happiness score in 2018 is {round(pop_whs_2018[0],2)}.')

x_adults_2018 = merged_df['2018 Happiness Score']
y_adults_2018 = merged_df['2018 Mortality (<5)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2018, y_adults_2018)
regressValues = x_adults_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2018, y_adults_2018)
plt.plot(x_adults_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Infant Mortality Rate (per 1k)')
plt.title('2018 Happiness Scores and Infant Mortality Rate (%)')
plt.show()
# Out:
# The correlation between infant mortality and world happiness score in 2018 is -0.65.

# %%
# 2019 Infant Mortality Rate and 2019 World Happiness

adults_2019 = merged_df.iloc[:, 34]
whs_2019 = merged_df.iloc[:, 62]
pop_whs_2019 = st.pearsonr(adults_2019, whs_2019)
print(f'The correlation between infant mortality and world happiness score in 2019 is {round(pop_whs_2019[0],2)}.')

x_adults_2019 = merged_df['2019 Happiness Score']
y_adults_2019 = merged_df['2019 Mortality (<5)']
slope, intercept, rvalue, pvalue, stderr = linregress(x_adults_2019, y_adults_2019)
regressValues = x_adults_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_adults_2019, y_adults_2019)
plt.plot(x_adults_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Infant Mortality Rate (per 1k)')
plt.title('2019 Happiness Scores and Infant Mortality Rate (%)')
plt.show()
# Out:
# The correlation between infant mortality and world happiness score in 2019 is -0.63.

# %% [markdown]
# ## Female Life Expectancy and World Happiness Score

# %%
# 2015 Female Life Expectancy and 2015 World Happiness

fle_2015 = merged_df.iloc[:, 35]
whs_2015 = merged_df.iloc[:, 58]
fle_whs_2015 = st.pearsonr(fle_2015, whs_2015)
print(f'The correlation between female life expectancy and world happiness score in 2015 is {round(fle_whs_2015[0],2)}.')

x_fle_2015 = merged_df['2015 Happiness Score']
y_fle_2015 = merged_df['2015 Female Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_fle_2015, y_fle_2015)
regressValues = x_fle_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_fle_2015, y_fle_2015)
plt.plot(x_fle_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Female Life Expectancy')
plt.title('2015 Happiness Scores and Female Life Expectancy')
plt.show()
# Out:
# The correlation between female life expectancy and world happiness score in 2015 is 0.76.

# %%
# 2016 Female Life Expectancy and 2016 World Happiness

fle_2016 = merged_df.iloc[:, 36]
whs_2016 = merged_df.iloc[:, 59]
fle_whs_2016 = st.pearsonr(fle_2016, whs_2016)
print(f'The correlation between female life expectancy and world happiness score in 2016 is {round(fle_whs_2016[0],2)}.')

x_fle_2016 = merged_df['2016 Happiness Score']
y_fle_2016 = merged_df['2016 Female Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_fle_2016, y_fle_2016)
regressValues = x_fle_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_fle_2016, y_fle_2016)
plt.plot(x_fle_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Female Life Expectancy')
plt.title('2016 Happiness Scores and Female Life Expectancy')
plt.show()
# Out:
# The correlation between female life expectancy and world happiness score in 2016 is 0.79.

# %%
# 2017 Female Life Expectancy and 2017 World Happiness

fle_2017 = merged_df.iloc[:, 37]
whs_2017 = merged_df.iloc[:, 60]
fle_whs_2017 = st.pearsonr(fle_2017, whs_2017)
print(f'The correlation between total unemployment and world happiness score in 2017 is {round(fle_whs_2017[0],2)}.')

x_fle_2017 = merged_df['2017 Happiness Score']
y_fle_2017 = merged_df['2017 Female Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_fle_2017, y_fle_2017)
regressValues = x_fle_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_fle_2017, y_fle_2017)
plt.plot(x_fle_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Female Life Expectancy')
plt.title('2017 Happiness Scores and Female Life Expentancy')
plt.show()
# Out:
# The correlation between total unemployment and world happiness score in 2017 is 0.79.

# %%
# 2018 Female Life Expectancy and 2018 World Happiness

fle_2018 = merged_df.iloc[:, 38]
whs_2018 = merged_df.iloc[:, 61]
fle_whs_2018 = st.pearsonr(fle_2018, whs_2018)
print(f'The correlation between female life expentancy and world happiness score in 2018 is {round(fle_whs_2018[0],2)}.')

x_fle_2018 = merged_df['2018 Happiness Score']
y_fle_2018 = merged_df[' 2018 Female Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_fle_2018, y_fle_2018)
regressValues = x_fle_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_fle_2018, y_fle_2018)
plt.plot(x_fle_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Female Life Expentancy')
plt.title('2018 Happiness Scores and Female Life Expectancy')
plt.show()
# Out:
# The correlation between female life expentancy and world happiness score in 2018 is 0.76.

# %% [markdown]
# ## Male Life Expectancy and World Happiness Score

# %%
# 2015 Male Life Expectancy and 2015 World Happiness

mle_2015 = merged_df.iloc[:, 39]
whs_2015 = merged_df.iloc[:, 58]
mle_whs_2015 = st.pearsonr(mle_2015, whs_2015)
print(f'The correlation between male life expectancy and world happiness score in 2015 is {round(mle_whs_2015[0],2)}.')

x_whs_2015 = merged_df['2015 Happiness Score']
y_mle_2015 = merged_df['2015 Male Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2015, y_mle_2015)
regressValues = x_whs_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2015, y_mle_2015)
plt.plot(x_whs_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Male Life Expectancy')
plt.title('2015 Happiness Scores and Male Life Expectancy')
plt.show()
# Out:
# The correlation between male life expectancy and world happiness score in 2015 is 0.78.

# %%
# 2016 Male Life Expectancy and 2016 World Happiness

mle_2016 = merged_df.iloc[:, 40]
whs_2016 = merged_df.iloc[:, 59]
mle_whs_2016 = st.pearsonr(mle_2016, whs_2016)
print(f'The correlation between Male Life Expectancy and world happiness score in 2016 is {round(mle_whs_2016[0],2)}.')

x_whs_2016 = merged_df['2016 Happiness Score']
y_mle_2016 = merged_df['2016 Male Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2016, y_mle_2016)
regressValues = x_whs_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2016, y_mle_2016)
plt.plot(x_whs_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Male Life Expectancy')
plt.title('2016 Happiness Scores and Male Life Expectancy')
plt.show()
# Out:
# The correlation between Male Life Expectancy and world happiness score in 2016 is 0.8.

# %%
# 2017 Male Life Expectancy and 2017 World Happiness

mle_2017 = merged_df.iloc[:, 41]
whs_2017 = merged_df.iloc[:, 60]
mle_whs_2017 = st.pearsonr(mle_2017, whs_2017)
print(f'The correlation between Male Life Expectancy and world happiness score in 2017 is {round(mle_whs_2017[0],2)}.')

x_whs_2017 = merged_df['2017 Happiness Score']
y_mle_2017 = merged_df['2017 Male Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2017, y_mle_2017)
regressValues = x_whs_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2017, y_mle_2017)
plt.plot(x_whs_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Male Life Expectancy')
plt.title('2017 Happiness Scores and Male Life Expectancy')
plt.show()
# Out:
# The correlation between Male Life Expectancy and world happiness score in 2017 is 0.8.

# %%
# 2018 Male Life Expectancy and 2018 World Happiness

mle_2018 = merged_df.iloc[:, 42]
whs_2018 = merged_df.iloc[:, 61]
mle_whs_2018 = st.pearsonr(mle_2018, whs_2018)
print(f'The correlation between Male Life Expectancy and world happiness score in 2018 is {round(mle_whs_2018[0],2)}.')

x_whs_2018 = merged_df['2018 Happiness Score']
y_mle_2018 = merged_df[' 2018 Male Life Expectancy']
slope, intercept, rvalue, pvalue, stderr = linregress(x_whs_2018, y_mle_2018)
regressValues = x_whs_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_whs_2018, y_mle_2018)
plt.plot(x_whs_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Male Life Expectancy')
plt.title('2018 Happiness Scores and Male Life Expectancy')
plt.show()
# Out:
# The correlation between Male Life Expectancy and world happiness score in 2018 is 0.79.

# %% [markdown]
# ## Total GDP and World Happiness Score

# %%
# 2015 Total GDP and World Happiness

gdp_2015 = merged_df.iloc[:, 48]
whs_2015 = merged_df.iloc[:, 58]
gdp_whs_2015 = st.pearsonr(gdp_2015, whs_2015)
print(f'The correlation between total gdp and world happiness score in 2015 is {round(gdp_whs_2015[0],2)}.')

x_gdp_2015 = merged_df['2015 Happiness Score']
y_gdp_2015 = merged_df['2015 Total GDP']
slope, intercept, rvalue, pvalue, stderr = linregress(x_gdp_2015, y_gdp_2015)
regressValues = x_gdp_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_gdp_2015, y_gdp_2015)
plt.plot(x_gdp_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total GDP')
plt.title('2015 Happiness Scores and Total GDP')
plt.show()
# Out:
# The correlation between total gdp and world happiness score in 2015 is 0.21.

# %%
# 2016 Total GDP and World Happiness

gdp_2016 = merged_df.iloc[:, 49]
whs_2016 = merged_df.iloc[:, 59]
gdp_whs_2016 = st.pearsonr(gdp_2016, whs_2016)
print(f'The correlation between total gdp and world happiness score in 2016 is {round(gdp_whs_2016[0],2)}.')

x_gdp_2016 = merged_df['2016 Happiness Score']
y_gdp_2016 = merged_df['2016 Total GDP']
slope, intercept, rvalue, pvalue, stderr = linregress(x_gdp_2016, y_gdp_2016)
regressValues = x_gdp_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_gdp_2016, y_gdp_2016)
plt.plot(x_gdp_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total GDP')
plt.title('2016 Happiness Scores and Total GDP')
plt.show()
# Out:
# The correlation between total gdp and world happiness score in 2016 is 0.21.

# %%
# 2017 Total GDP and World Happiness

gdp_2017 = merged_df.iloc[:, 50]
whs_2017 = merged_df.iloc[:, 60]
gdp_whs_2017 = st.pearsonr(gdp_2017, whs_2017)
print(f'The correlation between total gdp and world happiness score in 2017 is {round(gdp_whs_2017[0],2)}.')

x_gdp_2017 = merged_df['2017 Happiness Score']
y_gdp_2017 = merged_df['2017 Total GDP']
slope, intercept, rvalue, pvalue, stderr = linregress(x_gdp_2017, y_gdp_2017)
regressValues = x_gdp_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_gdp_2017, y_gdp_2017)
plt.plot(x_gdp_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total GDP')
plt.title('2017 Happiness Scores and Total GDP')
plt.show()
# Out:
# The correlation between total gdp and world happiness score in 2017 is 0.2.

# %%
# 2018 Total GDP and World Happiness

gdp_2018 = merged_df.iloc[:, 51]
whs_2018 = merged_df.iloc[:, 61]
gdp_whs_2018 = st.pearsonr(gdp_2018, whs_2018)
print(f'The correlation between total gdp and world happiness score in 2018 is {round(gdp_whs_2018[0],2)}.')

x_gdp_2018 = merged_df['2018 Happiness Score']
y_gdp_2018 = merged_df['2018 Total GDP']
slope, intercept, rvalue, pvalue, stderr = linregress(x_gdp_2018, y_gdp_2018)
regressValues = x_gdp_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_gdp_2018, y_gdp_2018)
plt.plot(x_gdp_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total GDP')
plt.title('2018 Happiness Scores and Total GDP')
plt.show()
# Out:
# The correlation between total gdp and world happiness score in 2018 is 0.18.

# %%
# 2019 Total GDP and World Happiness

gdp_2019 = merged_df.iloc[:, 52]
whs_2019 = merged_df.iloc[:, 62]
gdp_whs_2019 = st.pearsonr(gdp_2019, whs_2019)
print(f'The correlation between total gdp and world happiness score in 2019 is {round(gdp_whs_2019[0],2)}.')

x_gdp_2019 = merged_df['2019 Happiness Score']
y_gdp_2019 = merged_df['2019 Total GDP']
slope, intercept, rvalue, pvalue, stderr = linregress(x_gdp_2019, y_gdp_2019)
regressValues = x_gdp_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_gdp_2019, y_gdp_2019)
plt.plot(x_gdp_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total GDP')
plt.title('2019 Happiness Scores and Total GDP')
plt.show()
# Out:
# The correlation between total gdp and world happiness score in 2019 is 0.17.

# %% [markdown]
# ## Total Labor Force and World Happiness Score

# %%
# 2015 Total Labor and World Happiness

labor_2015 = merged_df.iloc[:, 53]
whs_2015 = merged_df.iloc[:, 58]
labor_whs_2015 = st.pearsonr(labor_2015, whs_2015)
print(f'The correlation between total labor force and world happiness score in 2015 is {round(labor_whs_2015[0],2)}.')

x_labor_2015 = merged_df['2015 Happiness Score']
y_labor_2015 = merged_df['2015 Total Labor Force']
slope, intercept, rvalue, pvalue, stderr = linregress(x_labor_2015, y_labor_2015)
regressValues = x_labor_2015 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_labor_2015, y_labor_2015)
plt.plot(x_labor_2015, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2015 Happiness Score')
plt.ylabel('2015 Total Labor Force')
plt.title('2015 Happiness Scores and Total Labor Force')
plt.show()
# Out:
# The correlation between total labor force and world happiness score in 2015 is -0.02.

# %%
# 2016 Total Labor and World Happiness

labor_2016 = merged_df.iloc[:, 54]
whs_2016 = merged_df.iloc[:, 59]
labor_whs_2016 = st.pearsonr(labor_2016, whs_2016)
print(f'The correlation between total labor force and world happiness score in 2016 is {round(labor_whs_2016[0],2)}.')

x_labor_2016 = merged_df['2016 Happiness Score']
y_labor_2016 = merged_df['2016 Total Labor Force']
slope, intercept, rvalue, pvalue, stderr = linregress(x_labor_2016, y_labor_2016)
regressValues = x_labor_2016 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_labor_2016, y_labor_2016)
plt.plot(x_labor_2016, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2016 Happiness Score')
plt.ylabel('2016 Total Labor Force')
plt.title('2016 Happiness Scores and Total Labor Force')
plt.show()
# Out:
# The correlation between total labor force and world happiness score in 2016 is -0.02.

# %%
# 2017 Total Labor and World Happiness

labor_2017 = merged_df.iloc[:, 55]
whs_2017 = merged_df.iloc[:, 60]
labor_whs_2017 = st.pearsonr(labor_2017, whs_2017)
print(f'The correlation between total labor force and world happiness score in 2017 is {round(labor_whs_2017[0],2)}.')

x_labor_2017 = merged_df['2017 Happiness Score']
y_labor_2017 = merged_df['2017 Total Labor Force']
slope, intercept, rvalue, pvalue, stderr = linregress(x_labor_2017, y_labor_2017)
regressValues = x_labor_2017 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_labor_2017, y_labor_2017)
plt.plot(x_labor_2017, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2017 Happiness Score')
plt.ylabel('2017 Total Labor Force')
plt.title('2017 Happiness Scores and Total Labor Force')
plt.show()
# Out:
# The correlation between total labor force and world happiness score in 2017 is -0.03.

# %%
# 2018 Total Labor and World Happiness

labor_2018 = merged_df.iloc[:, 56]
whs_2018 = merged_df.iloc[:, 61]
labor_whs_2018 = st.pearsonr(labor_2018, whs_2018)
print(f'The correlation between total labor force and world happiness score in 2018 is {round(labor_whs_2018[0],2)}.')

x_labor_2018 = merged_df['2018 Happiness Score']
y_labor_2018 = merged_df['2018 Total Labor Force']
slope, intercept, rvalue, pvalue, stderr = linregress(x_labor_2018, y_labor_2018)
regressValues = x_labor_2018 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_labor_2018, y_labor_2018)
plt.plot(x_labor_2018, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2018 Happiness Score')
plt.ylabel('2018 Total Labor Force')
plt.title('2018 Happiness Scores and Total Labor Force')
plt.show()
# Out:
# The correlation between total labor force and world happiness score in 2018 is -0.05.

# %%
# 2019 Total Labor and World Happiness

labor_2019 = merged_df.iloc[:, 57]
whs_2019 = merged_df.iloc[:, 62]
labor_whs_2019 = st.pearsonr(labor_2019, whs_2019)
print(f'The correlation between total labor force and world happiness score in 2019 is {round(labor_whs_2019[0],2)}.')

x_labor_2019 = merged_df['2019 Happiness Score']
y_labor_2019 = merged_df['2019 Total Labor Force']
slope, intercept, rvalue, pvalue, stderr = linregress(x_labor_2019, y_labor_2019)
regressValues = x_labor_2019 * slope + intercept
lineEq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_labor_2019, y_labor_2019)
plt.plot(x_labor_2019, regressValues,"r-")
plt.annotate(lineEq,(6,10),fontsize=15,color="red")
plt.xlabel('2019 Happiness Score')
plt.ylabel('2019 Total Labor Force')
plt.title('2019 Happiness Scores and Total Labor Force')
plt.show()
# Out:
# The correlation between total labor force and world happiness score in 2019 is -0.07.
